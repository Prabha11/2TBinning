# %%
import os
import csv
import numpy as np
from scipy.stats import norm

with open('simBG_output.L2_summary') as csv_file:
    summary_array = np.asarray(list(csv.reader(csv_file, delimiter=',')))
#     print (summary_array,"\n")
    
    final_array = [[0]*2]*len(summary_array)
#     final_array = summary_array[:,0]
    
with open('simBG_output.unbinned_contiges') as csv_file:
    unbinned_array =  np.asarray(list(csv.reader(csv_file, delimiter=',')))
    
    for i in range(len(summary_array)):    
        final_array[i][0] = summary_array[i][0]
        print(final_array[i][0])
    print(final_array)
#         final_array[i][0] = summary_array[i][0]
#         if summary_array[i][6] == "0" :
#             print(summary_array[i][0],"Zero uncertainity..")
#         else :
#             print(summary_array[i][0], " - bin\n")
#             for j in range(len(unbinned_array)):
#                 prob = norm.pdf(float(unbinned_array[j][6]),float(summary_array[i][3]),float(summary_array[i][6]))
#                 if prob>=16.75 :
#                     print(prob)
#     prob = norm.pdf(43.64,43.73,0.825)
#     print(final_array)
# Out:
# 11
# 21
# 22
# 31
# 32
# 33
# 34
# 41
# 51
# 61
# [['61', 0], ['61', 0], ['61', 0], ['61', 0], ['61', 0], ['61', 0], ['61', 0], ['61', 0], ['61', 0], ['61', 0]]

# %%
with open('simBG_output.unbinned_contiges') as csv_file:
    csv_reader_unbinned = csv.reader(csv_file, delimiter=',')
    for row in csv_reader_unbinned:
        print(row)
# Out:
# ['contig2', '0', '-0.08653633036797', '-0.999968723605306', '110.033847749664', '0.171108668305003', '0.531574740207834', '1251']
# ['contig3', '0', '-0.0735369438864603', '-0.999965892686401', '198.276457291031', '0.320085576654883', '0.64022770398482', '2635']
# ['contig4', '0', '-0.0719207231554489', '-0.999979527026035', '205.837971047031', '0.257559276925693', '0.427805575411008', '2798']
# ['contig12', '0', '-0.0715373072905482', '-0.999948193672678', '199.184286290097', '0.392244467528435', '0.483104344597104', '2693']
# ['contig19', '0', '-0.0726927616748174', '-0.999560448120569', '88.1270666970043', '0.553289106060207', '0.431635388739946', '1119']
# ['contig20', '0', '-0.0737415280151737', '-0.99994861404793', '90.0089452429399', '0.163936888620079', '0.362226277372263', '1096']
# ['contig30', '0', '-0.0704458535975796', '-0.999539405012586', '82.0642624213298', '0.445797533175831', '0.64299424184261', '1042']
# ...
